# %% [markdown]
# ## Mask Detection Implementation ##
#
# Detect if a person on the web camera triggered using OpenCv is wearing mask or not using the Mask_NoMask.h5 model trained using tensorflow.

# %%
## Import tensorflow lib to load the model 
import tensorflow as tf

# %%
# conda install conda-forge::opencv
# Out:
# Channels:
#  - defaults
#  - conda-forge
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: / warning  libmamba Added empty dependency for problem type SOLVER_RULE_UPDATE
# done
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3
#
#   added / updated specs:
#     - conda-forge::opencv
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     aom-3.9.1                  |       h7bae524_0         2.1 MB  conda-forge
#     arrow-cpp-13.0.0           |  hce30654_49_cpu          42 KB  conda-forge
#     aws-c-auth-0.7.22          |      h8a62e84_10          89 KB  conda-forge
#     aws-c-cal-0.7.1            |       h94d0942_1          39 KB  conda-forge
#     aws-c-common-0.9.23        |       h99b78c6_0         215 KB  conda-forge
#     aws-c-compression-0.2.18   |       h94d0942_7          18 KB  conda-forge
#     aws-c-event-stream-0.4.2   |      hb74cd8f_15          46 KB  conda-forge
#     aws-c-http-0.8.2           |       had1507a_6         148 KB  conda-forge
#     aws-c-io-0.14.10           |       hcdb10ff_1         134 KB  conda-forge
#     aws-c-mqtt-0.10.4          |       h856d8ab_8         115 KB  conda-forge
#     aws-c-s3-0.6.0             |       ha9fd6de_2          92 KB  conda-forge
#     aws-c-sdkutils-0.1.16      |       h94d0942_3          48 KB  conda-forge
#     aws-checksums-0.1.18       |       h94d0942_7          48 KB  conda-forge
#     aws-crt-cpp-0.27.3         |       h9d3339c_2         222 KB  conda-forge
#     aws-sdk-cpp-1.11.329       |       he6360a2_9         3.2 MB  conda-forge
#     blosc-1.21.6               |       h5499902_0          32 KB  conda-forge
#     boost-cpp-1.85.0           |       h103c1d6_4          18 KB  conda-forge
#     brotli-1.0.7               |       hc377ac9_0         379 KB
#     brotli-bin-1.1.0           |       hd74edd7_2          16 KB  conda-forge
#     c-ares-1.34.3              |       h5505292_0         175 KB  conda-forge
#     c-blosc2-2.15.1            |       h5063078_0         236 KB  conda-forge
#     cached-property-1.5.2      |             py_0          11 KB
#     cairo-1.18.0               |       hb4a6bf7_3         878 KB  conda-forge
#     cfitsio-4.4.1              |       hd313823_2         776 KB  conda-forge
#     charls-2.4.2               |       h13dd4ca_0         114 KB  conda-forge
#     curl-8.10.1                |       h13a7ad3_0         154 KB  conda-forge
#     cyrus-sasl-2.1.27          |       h60b93bd_7         206 KB  conda-forge
#     dask-2024.5.0              |  py312hca03da5_0           7 KB
#     dask-core-2024.5.0         |  py312hca03da5_0         2.9 MB
#     dask-expr-1.1.0            |  py312hca03da5_0         468 KB
#     distributed-2024.5.0       |  py312hca03da5_0         1.7 MB
#     ffmpeg-6.1.2               | gpl_hbafc610_106         8.3 MB  conda-forge
#     font-ttf-dejavu-sans-mono-2.37|       hd3eb1b0_0         335 KB
#     font-ttf-inconsolata-2.001 |       hcb22688_0          83 KB
#     font-ttf-source-code-pro-2.030|       hd3eb1b0_0         654 KB
#     font-ttf-ubuntu-0.83       |       h8b1ccd4_0         1.5 MB
#     fontconfig-2.15.0          |       h1383a14_1         229 KB  conda-forge
#     fonts-anaconda-1           |       h8fa9717_0           3 KB
#     fonts-conda-ecosystem-1    |       hd3eb1b0_0           5 KB
#     freetype-2.12.1            |       hadb7bae_2         582 KB  conda-forge
#     fribidi-1.0.10             |       h1a28f6b_0          60 KB
#     glib-2.82.2                |       hb1db9eb_0         571 KB  conda-forge
#     glib-tools-2.82.2          |       h25d4a46_0          98 KB  conda-forge
#     glog-0.7.1                 |       heb240a5_0         110 KB  conda-forge
#     gmp-6.3.0                  |       h7bae524_2         357 KB  conda-forge
#     graphite2-1.3.14           |       hc377ac9_1          75 KB
#     grpcio-1.62.2              |  py312h17030e7_0         939 KB  conda-forge
#     gst-plugins-base-1.24.7    |       hb49d354_0         1.9 MB  conda-forge
#     gstreamer-1.24.7           |       hc3f5269_0         1.3 MB  conda-forge
#     h5py-3.12.1                |nompi_py312h3cd0824_102         1.1 MB  conda-forge
#     harfbuzz-9.0.0             |       h997cde5_1         1.3 MB  conda-forge
#     hdf5-1.14.3                |nompi_hec07895_105         3.3 MB  conda-forge
#     icu-75.1                   |       hfee45f7_0        11.3 MB  conda-forge
#     imagecodecs-2024.9.22      |  py312h232c411_0         1.7 MB  conda-forge
#     imath-3.1.12               |       h025cafa_0         149 KB  conda-forge
#     jasper-4.2.4               |       h6c4e4ef_0         570 KB  conda-forge
#     krb5-1.21.3                |       hf3e1bf2_0         1.2 MB
#     lame-3.100                 |       h1a28f6b_0         312 KB
#     lcms2-2.16                 |       ha0e7c42_0         207 KB  conda-forge
#     lerc-4.0.0                 |       h9a09cb3_0         211 KB  conda-forge
#     libaec-1.1.3               |       hebf3989_0          28 KB  conda-forge
#     libarchive-3.7.4           |       h83d404f_0         758 KB  conda-forge
#     libarrow-13.0.0            |  h4d6bf39_49_cpu        17.3 MB  conda-forge
#     libasprintf-0.22.5         |       h8414b35_3          40 KB  conda-forge
#     libass-0.17.3              |       hf20b609_0         114 KB  conda-forge
#     libavif-1.1.1              |       h45b7238_2          39 KB  conda-forge
#     libavif16-1.1.1            |       h45b7238_2          95 KB  conda-forge
#     libblas-3.9.0              |1_h2ec9a88_netlib         173 KB  conda-forge
#     libboost-1.85.0            |       hf763ba5_4         1.9 MB  conda-forge
#     libboost-devel-1.85.0      |       hf450f58_4          40 KB  conda-forge
#     libboost-headers-1.85.0    |       hce30654_4        13.5 MB  conda-forge
#     libbrotlicommon-1.1.0      |       hd74edd7_2          67 KB  conda-forge
#     libbrotlidec-1.1.0         |       hd74edd7_2          28 KB  conda-forge
#     libbrotlienc-1.1.0         |       hd74edd7_2         273 KB  conda-forge
#     libcblas-3.9.0             |1_h9886b1c_netlib          43 KB
#     libclang-19.1.4            |default_hf90f093_0          23 KB  conda-forge
#     libclang-cpp17-17.0.6      |default_h146c034_7        11.8 MB  conda-forge
#     libclang13-19.1.4          |default_h81d93ff_0         8.1 MB  conda-forge
#     libcrc32c-1.1.2            |       hc377ac9_0          18 KB
#     libcurl-8.10.1             |       h13a7ad3_0         371 KB  conda-forge
#     libcxx-19.1.4              |       ha82da77_0         508 KB  conda-forge
#     libdeflate-1.22            |       hd74edd7_0          53 KB  conda-forge
#     libexpat-2.6.3             |       hf9b8971_0          62 KB  conda-forge
#     libgettextpo-0.22.5        |       h8414b35_3         156 KB  conda-forge
#     libgfortran-5.0.0          |13_2_0_hd922786_3         108 KB  conda-forge
#     libgfortran5-13.2.0        |       hf226fd6_3         974 KB  conda-forge
#     libglib-2.82.2             |       h07bd6cf_0         3.5 MB  conda-forge
#     libgoogle-cloud-2.26.0     |       hfe08963_0         841 KB  conda-forge
#     libgoogle-cloud-storage-2.26.0|       h1466eeb_0         519 KB  conda-forge
#     libgrpc-1.62.2             |       h9c18a4f_0         4.8 MB  conda-forge
#     libhwloc-2.11.1            |default_h7685b71_1000         2.2 MB  conda-forge
#     libhwy-1.1.0               |       h2ffa867_0         443 KB  conda-forge
#     libiconv-1.17              |       h0d3ecfb_2         661 KB  conda-forge
#     libintl-0.22.5             |       h8414b35_3          79 KB  conda-forge
#     libintl-devel-0.22.5       |       h8414b35_3          38 KB  conda-forge
#     libjpeg-turbo-3.0.3        |       h80987f9_0         577 KB
#     libjxl-0.11.0              |       hbabf80f_2         848 KB  conda-forge
#     liblapack-3.9.0            |1_h9886b1c_netlib         2.2 MB
#     liblapacke-3.9.0           |1_h9886b1c_netlib         377 KB
#     libllvm14-14.0.6           |       hd1a9a77_4        19.6 MB  conda-forge
#     libllvm17-17.0.6           |       h5090b49_2        23.5 MB  conda-forge
#     libllvm19-19.1.4           |       hc4b4ae8_0        25.8 MB  conda-forge
#     libnghttp2-1.64.0          |       h6d7220d_0         553 KB  conda-forge
#     libntlm-1.5                |       h1a28f6b_0          29 KB
#     libogg-1.3.5               |       h1a28f6b_1         197 KB
#     libopencv-4.10.0           |headless_py312haa779ad_6        20.8 MB  conda-forge
#     libopenvino-2024.4.0       |       h49f535f_0         3.8 MB  conda-forge
#     libopenvino-arm-cpu-plugin-2024.4.0|       h49f535f_0         7.1 MB  conda-forge
#     libopenvino-auto-batch-plugin-2024.4.0|       h8a2fcec_0         101 KB  conda-forge
#     libopenvino-auto-plugin-2024.4.0|       h8a2fcec_0         205 KB  conda-forge
#     libopenvino-hetero-plugin-2024.4.0|       h868cbb4_0         169 KB  conda-forge
#     libopenvino-ir-frontend-2024.4.0|       h868cbb4_0         168 KB  conda-forge
#     libopenvino-onnx-frontend-2024.4.0|       hf4ed89a_0         1.2 MB  conda-forge
#     libopenvino-paddle-frontend-2024.4.0|       hf4ed89a_0         411 KB  conda-forge
#     libopenvino-pytorch-frontend-2024.4.0|       hf9b8971_0         747 KB  conda-forge
#     libopenvino-tensorflow-frontend-2024.4.0|       h94307f2_0         923 KB  conda-forge
#     libopenvino-tensorflow-lite-frontend-2024.4.0|       hf9b8971_0         361 KB  conda-forge
#     libopus-1.3.1              |       h80987f9_1         317 KB
#     libpng-1.6.44              |       hc14010f_0         257 KB  conda-forge
#     libpq-16.5                 |       h0224a88_0         2.3 MB  conda-forge
#     libprotobuf-4.25.3         |       hc39d83c_1         2.1 MB  conda-forge
#     libre2-11-2023.09.01       |       h7b2c953_2         167 KB  conda-forge
#     libsolv-0.7.30             |       h6c9b7f8_0         378 KB  conda-forge
#     libsqlite-3.47.0           |       hbaaea75_1         818 KB  conda-forge
#     libssh2-1.11.0             |       h7a5bd25_0         250 KB  conda-forge
#     libthrift-0.19.0           |       h026a170_1         323 KB  conda-forge
#     libtiff-4.7.0              |       hfce79cd_1         358 KB  conda-forge
#     libutf8proc-2.8.0          |       h1a8c8d9_0         101 KB  conda-forge
#     libvorbis-1.3.7            |       h1a28f6b_0         583 KB
#     libvpx-1.14.1              |       h7bae524_0         1.1 MB  conda-forge
#     libwebp-base-1.4.0         |       h93a5062_0         281 KB  conda-forge
#     libxcb-1.17.0              |       hdb1d25a_0         316 KB  conda-forge
#     libxml2-2.13.5             |       hbbdcc80_0         569 KB  conda-forge
#     libzlib-1.3.1              |       h8359307_2          45 KB  conda-forge
#     llvm-openmp-19.1.4         |       hdb05f8b_0         275 KB  conda-forge
#     mysql-9.0.1                |       h44b9a77_0         169 KB  conda-forge
#     mysql-client-9.0.1         |       h0e80b4a_0         4.1 MB  conda-forge
#     mysql-common-9.0.1         |       h1687695_0         616 KB  conda-forge
#     mysql-devel-9.0.1          |       h1687695_0         1.5 MB  conda-forge
#     mysql-libs-9.0.1           |       h0e80b4a_0         1.3 MB  conda-forge
#     mysql-server-9.0.1         |       h2ac2235_0        15.7 MB  conda-forge
#     ncurses-6.5                |       h7bae524_1         784 KB  conda-forge
#     nspr-4.36                  |       h5833ebf_0         198 KB  conda-forge
#     nss-3.106                  |       h6f44f80_0         1.7 MB  conda-forge
#     opencv-4.10.0              |headless_py312hf580477_6          26 KB  conda-forge
#     openexr-3.2.2              |       hab01212_2         1.2 MB  conda-forge
#     openh264-2.4.1             |       hebf3989_0         585 KB  conda-forge
#     openssl-3.4.0              |       h39f12f2_0         2.8 MB  conda-forge
#     orc-2.0.1                  |       h47ade37_1         407 KB  conda-forge
#     pcre2-10.44                |       h297a79d_2         604 KB  conda-forge
#     pillow-11.0.0              |  py312haf37ca6_0        39.8 MB  conda-forge
#     pixman-0.43.4              |       hebf3989_0         194 KB  conda-forge
#     pthread-stubs-0.3          |       h1a28f6b_1           7 KB
#     pugixml-1.14               |       h13dd4ca_0          90 KB  conda-forge
#     py-opencv-4.10.0           |headless_py312hd31a7ba_6         1.1 MB  conda-forge
#     pyarrow-13.0.0             |py312hd940a8a_49_cpu         3.5 MB  conda-forge
#     pytables-3.10.1            |  py312h36a7e55_1         1.7 MB  conda-forge
#     python-3.12.7              |h739c21a_0_cpython        12.4 MB  conda-forge
#     python_abi-3.12            |          5_cp312           6 KB  conda-forge
#     qt-main-5.15.15            |       h7d33341_0        47.7 MB  conda-forge
#     rav1e-0.6.6                |       h69fbcac_2         1.5 MB  conda-forge
#     re2-2023.09.01             |       h4cba328_2          26 KB  conda-forge
#     sqlite-3.47.0              |       hcd14bea_1         821 KB  conda-forge
#     streamlit-1.40.1           |     pyhd8ed1ab_0         6.7 MB  conda-forge
#     svt-av1-2.3.0              |       hf24288c_0         1.3 MB  conda-forge
#     tbb-2021.13.0              |       h7b3277c_0         113 KB  conda-forge
#     tensorflow-2.17.0          |cpu_py312hb6b62e0_0          40 KB  conda-forge
#     tensorflow-base-2.17.0     |cpu_py312hdc9440d_0       150.7 MB  conda-forge
#     tensorflow-estimator-2.17.0|cpu_py312ha916e62_0         681 KB  conda-forge
#     tk-8.6.13                  |       h5083fa2_1         3.0 MB  conda-forge
#     tzlocal-5.2                |  py312hca03da5_0          44 KB
#     validators-0.18.2          |     pyhd3eb1b0_0          18 KB
#     x264-1!164.3095            |       h57fd34a_2         700 KB  conda-forge
#     x265-3.5                   |       hbc6ce65_3         1.7 MB  conda-forge
#     xorg-libxau-1.0.11         |       hd74edd7_1          13 KB  conda-forge
#     xorg-libxdmcp-1.1.5        |       hd74edd7_0          18 KB  conda-forge
#     zfp-1.0.1                  |       h1c5d8ea_2         195 KB  conda-forge
#     zlib-1.3.1                 |       h8359307_2          76 KB  conda-forge
#     zlib-ng-2.2.2              |       hf9b8971_0          85 KB  conda-forge
#     zstd-1.5.6                 |       hb46c0d2_0         396 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       548.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   cached-property    pkgs/main/noarch::cached-property-1.5.2-py_0
#   cairo              conda-forge/osx-arm64::cairo-1.18.0-hb4a6bf7_3
#   ffmpeg             conda-forge/osx-arm64::ffmpeg-6.1.2-gpl_hbafc610_106
#   font-ttf-dejavu-s~ pkgs/main/noarch::font-ttf-dejavu-sans-mono-2.37-hd3eb1b0_0
#   font-ttf-inconsol~ pkgs/main/noarch::font-ttf-inconsolata-2.001-hcb22688_0
#   font-ttf-source-c~ pkgs/main/noarch::font-ttf-source-code-pro-2.030-hd3eb1b0_0
#   font-ttf-ubuntu    pkgs/main/noarch::font-ttf-ubuntu-0.83-h8b1ccd4_0
#   fontconfig         conda-forge/osx-arm64::fontconfig-2.15.0-h1383a14_1
#   fonts-anaconda     pkgs/main/noarch::fonts-anaconda-1-h8fa9717_0
#   fonts-conda-ecosy~ pkgs/main/noarch::fonts-conda-ecosystem-1-hd3eb1b0_0
#   fribidi            pkgs/main/osx-arm64::fribidi-1.0.10-h1a28f6b_0
#   gmp                conda-forge/osx-arm64::gmp-6.3.0-h7bae524_2
#   graphite2          pkgs/main/osx-arm64::graphite2-1.3.14-hc377ac9_1
#   harfbuzz           conda-forge/osx-arm64::harfbuzz-9.0.0-h997cde5_1
#   imath              conda-forge/osx-arm64::imath-3.1.12-h025cafa_0
#   jasper             conda-forge/osx-arm64::jasper-4.2.4-h6c4e4ef_0
#   lame               pkgs/main/osx-arm64::lame-3.100-h1a28f6b_0
#   libarrow           conda-forge/osx-arm64::libarrow-13.0.0-h4d6bf39_49_cpu
#   libasprintf        conda-forge/osx-arm64::libasprintf-0.22.5-h8414b35_3
#   libass             conda-forge/osx-arm64::libass-0.17.3-hf20b609_0
#   libavif16          conda-forge/osx-arm64::libavif16-1.1.1-h45b7238_2
#   libblas            conda-forge/osx-arm64::libblas-3.9.0-1_h2ec9a88_netlib
#   libboost-devel     conda-forge/osx-arm64::libboost-devel-1.85.0-hf450f58_4
#   libboost-headers   conda-forge/osx-arm64::libboost-headers-1.85.0-hce30654_4
#   libcblas           pkgs/main/osx-arm64::libcblas-3.9.0-1_h9886b1c_netlib
#   libclang-cpp17     conda-forge/osx-arm64::libclang-cpp17-17.0.6-default_h146c034_7
#   libcrc32c          pkgs/main/osx-arm64::libcrc32c-1.1.2-hc377ac9_0
#   libexpat           conda-forge/osx-arm64::libexpat-2.6.3-hf9b8971_0
#   libgettextpo       conda-forge/osx-arm64::libgettextpo-0.22.5-h8414b35_3
#   libgoogle-cloud    conda-forge/osx-arm64::libgoogle-cloud-2.26.0-hfe08963_0
#   libgoogle-cloud-s~ conda-forge/osx-arm64::libgoogle-cloud-storage-2.26.0-h1466eeb_0
#   libhwloc           conda-forge/osx-arm64::libhwloc-2.11.1-default_h7685b71_1000
#   libhwy             conda-forge/osx-arm64::libhwy-1.1.0-h2ffa867_0
#   libintl            conda-forge/osx-arm64::libintl-0.22.5-h8414b35_3
#   libintl-devel      conda-forge/osx-arm64::libintl-devel-0.22.5-h8414b35_3
#   libjpeg-turbo      pkgs/main/osx-arm64::libjpeg-turbo-3.0.3-h80987f9_0
#   libjxl             conda-forge/osx-arm64::libjxl-0.11.0-hbabf80f_2
#   liblapack          pkgs/main/osx-arm64::liblapack-3.9.0-1_h9886b1c_netlib
#   liblapacke         pkgs/main/osx-arm64::liblapacke-3.9.0-1_h9886b1c_netlib
#   libllvm17          conda-forge/osx-arm64::libllvm17-17.0.6-h5090b49_2
#   libllvm19          conda-forge/osx-arm64::libllvm19-19.1.4-hc4b4ae8_0
#   libntlm            pkgs/main/osx-arm64::libntlm-1.5-h1a28f6b_0
#   libogg             pkgs/main/osx-arm64::libogg-1.3.5-h1a28f6b_1
#   libopencv          conda-forge/osx-arm64::libopencv-4.10.0-headless_py312haa779ad_6
#   libopenvino        conda-forge/osx-arm64::libopenvino-2024.4.0-h49f535f_0
#   libopenvino-arm-c~ conda-forge/osx-arm64::libopenvino-arm-cpu-plugin-2024.4.0-h49f535f_0
#   libopenvino-auto-~ conda-forge/osx-arm64::libopenvino-auto-batch-plugin-2024.4.0-h8a2fcec_0
#   libopenvino-auto-~ conda-forge/osx-arm64::libopenvino-auto-plugin-2024.4.0-h8a2fcec_0
#   libopenvino-heter~ conda-forge/osx-arm64::libopenvino-hetero-plugin-2024.4.0-h868cbb4_0
#   libopenvino-ir-fr~ conda-forge/osx-arm64::libopenvino-ir-frontend-2024.4.0-h868cbb4_0
#   libopenvino-onnx-~ conda-forge/osx-arm64::libopenvino-onnx-frontend-2024.4.0-hf4ed89a_0
#   libopenvino-paddl~ conda-forge/osx-arm64::libopenvino-paddle-frontend-2024.4.0-hf4ed89a_0
#   libopenvino-pytor~ conda-forge/osx-arm64::libopenvino-pytorch-frontend-2024.4.0-hf9b8971_0
#   libopenvino-tenso~ conda-forge/osx-arm64::libopenvino-tensorflow-frontend-2024.4.0-h94307f2_0
#   libopenvino-tenso~ conda-forge/osx-arm64::libopenvino-tensorflow-lite-frontend-2024.4.0-hf9b8971_0
#   libopus            pkgs/main/osx-arm64::libopus-1.3.1-h80987f9_1
#   libre2-11          conda-forge/osx-arm64::libre2-11-2023.09.01-h7b2c953_2
#   libsqlite          conda-forge/osx-arm64::libsqlite-3.47.0-hbaaea75_1
#   libutf8proc        conda-forge/osx-arm64::libutf8proc-2.8.0-h1a8c8d9_0
#   libvorbis          pkgs/main/osx-arm64::libvorbis-1.3.7-h1a28f6b_0
#   libvpx             conda-forge/osx-arm64::libvpx-1.14.1-h7bae524_0
#   libxcb             conda-forge/osx-arm64::libxcb-1.17.0-hdb1d25a_0
#   libzlib            conda-forge/osx-arm64::libzlib-1.3.1-h8359307_2
#   mysql-client       conda-forge/osx-arm64::mysql-client-9.0.1-h0e80b4a_0
#   mysql-common       conda-forge/osx-arm64::mysql-common-9.0.1-h1687695_0
#   mysql-devel        conda-forge/osx-arm64::mysql-devel-9.0.1-h1687695_0
#   mysql-libs         conda-forge/osx-arm64::mysql-libs-9.0.1-h0e80b4a_0
#   mysql-server       conda-forge/osx-arm64::mysql-server-9.0.1-h2ac2235_0
#   nspr               conda-forge/osx-arm64::nspr-4.36-h5833ebf_0
#   nss                conda-forge/osx-arm64::nss-3.106-h6f44f80_0
#   opencv             conda-forge/osx-arm64::opencv-4.10.0-headless_py312hf580477_6
#   openexr            conda-forge/osx-arm64::openexr-3.2.2-hab01212_2
#   openh264           conda-forge/osx-arm64::openh264-2.4.1-hebf3989_0
#   pixman             conda-forge/osx-arm64::pixman-0.43.4-hebf3989_0
#   pthread-stubs      pkgs/main/osx-arm64::pthread-stubs-0.3-h1a28f6b_1
#   pugixml            conda-forge/osx-arm64::pugixml-1.14-h13dd4ca_0
#   py-opencv          conda-forge/osx-arm64::py-opencv-4.10.0-headless_py312hd31a7ba_6
#   python_abi         conda-forge/osx-arm64::python_abi-3.12-5_cp312
#   rav1e              conda-forge/osx-arm64::rav1e-0.6.6-h69fbcac_2
#   svt-av1            conda-forge/osx-arm64::svt-av1-2.3.0-hf24288c_0
#   tzlocal            pkgs/main/osx-arm64::tzlocal-5.2-py312hca03da5_0
#   validators         pkgs/main/noarch::validators-0.18.2-pyhd3eb1b0_0
#   x264               conda-forge/osx-arm64::x264-1!164.3095-h57fd34a_2
#   x265               conda-forge/osx-arm64::x265-3.5-hbc6ce65_3
#   xorg-libxau        conda-forge/osx-arm64::xorg-libxau-1.0.11-hd74edd7_1
#   xorg-libxdmcp      conda-forge/osx-arm64::xorg-libxdmcp-1.1.5-hd74edd7_0
#
# The following packages will be REMOVED:
#
#   jpeg-9e-h80987f9_3
#
# The following packages will be UPDATED:
#
#   aom                       pkgs/main::aom-3.6.0-h313beb8_0 --> conda-forge::aom-3.9.1-h7bae524_0
#   aws-c-auth         pkgs/main::aws-c-auth-0.6.19-h80987f9~ --> conda-forge::aws-c-auth-0.7.22-h8a62e84_10
#   aws-c-cal          pkgs/main::aws-c-cal-0.5.20-h80987f9_0 --> conda-forge::aws-c-cal-0.7.1-h94d0942_1
#   aws-c-common       pkgs/main::aws-c-common-0.8.5-h80987f~ --> conda-forge::aws-c-common-0.9.23-h99b78c6_0
#   aws-c-compression  pkgs/main::aws-c-compression-0.2.16-h~ --> conda-forge::aws-c-compression-0.2.18-h94d0942_7
#   aws-c-event-stream pkgs/main::aws-c-event-stream-0.2.15-~ --> conda-forge::aws-c-event-stream-0.4.2-hb74cd8f_15
#   aws-c-http         pkgs/main::aws-c-http-0.6.25-h80987f9~ --> conda-forge::aws-c-http-0.8.2-had1507a_6
#   aws-c-io           pkgs/main::aws-c-io-0.13.10-h80987f9_0 --> conda-forge::aws-c-io-0.14.10-hcdb10ff_1
#   aws-c-mqtt         pkgs/main::aws-c-mqtt-0.7.13-h80987f9~ --> conda-forge::aws-c-mqtt-0.10.4-h856d8ab_8
#   aws-c-s3            pkgs/main::aws-c-s3-0.1.51-h80987f9_0 --> conda-forge::aws-c-s3-0.6.0-ha9fd6de_2
#   aws-c-sdkutils     pkgs/main::aws-c-sdkutils-0.1.6-h8098~ --> conda-forge::aws-c-sdkutils-0.1.16-h94d0942_3
#   aws-checksums      pkgs/main::aws-checksums-0.1.13-h8098~ --> conda-forge::aws-checksums-0.1.18-h94d0942_7
#   aws-crt-cpp        pkgs/main::aws-crt-cpp-0.18.16-h313be~ --> conda-forge::aws-crt-cpp-0.27.3-h9d3339c_2
#   aws-sdk-cpp        pkgs/main::aws-sdk-cpp-1.10.55-h313be~ --> conda-forge::aws-sdk-cpp-1.11.329-he6360a2_9
#   blosc                  pkgs/main::blosc-1.21.3-h313beb8_0 --> conda-forge::blosc-1.21.6-h5499902_0
#   boost-cpp          pkgs/main::boost-cpp-1.82.0-h48ca7d4_2 --> conda-forge::boost-cpp-1.85.0-h103c1d6_4
#   brotli-bin         pkgs/main::brotli-bin-1.0.9-h80987f9_8 --> conda-forge::brotli-bin-1.1.0-hd74edd7_2
#   c-ares                pkgs/main::c-ares-1.19.1-h80987f9_0 --> conda-forge::c-ares-1.34.3-h5505292_0
#   c-blosc2            pkgs/main::c-blosc2-2.12.0-h7df6c2f_0 --> conda-forge::c-blosc2-2.15.1-h5063078_0
#   cfitsio               pkgs/main::cfitsio-3.470-h7f6438f_7 --> conda-forge::cfitsio-4.4.1-hd313823_2
#   charls                 pkgs/main::charls-2.2.0-hc377ac9_0 --> conda-forge::charls-2.4.2-h13dd4ca_0
#   curl                     pkgs/main::curl-8.9.1-h02f6b3c_0 --> conda-forge::curl-8.10.1-h13a7ad3_0
#   freetype            pkgs/main::freetype-2.12.1-h1192e45_0 --> conda-forge::freetype-2.12.1-hadb7bae_2
#   glib                    pkgs/main::glib-2.78.4-h313beb8_0 --> conda-forge::glib-2.82.2-hb1db9eb_0
#   glib-tools         pkgs/main::glib-tools-2.78.4-h313beb8~ --> conda-forge::glib-tools-2.82.2-h25d4a46_0
#   glog                     pkgs/main::glog-0.5.0-h313beb8_1 --> conda-forge::glog-0.7.1-heb240a5_0
#   gst-plugins-base   pkgs/main::gst-plugins-base-1.14.1-h3~ --> conda-forge::gst-plugins-base-1.24.7-hb49d354_0
#   gstreamer          pkgs/main::gstreamer-1.14.1-h80987f9_1 --> conda-forge::gstreamer-1.24.7-hc3f5269_0
#   h5py               pkgs/main::h5py-3.11.0-py312haac6407_0 --> conda-forge::h5py-3.12.1-nompi_py312h3cd0824_102
#   hdf5                    pkgs/main::hdf5-1.12.1-h05c076b_3 --> conda-forge::hdf5-1.14.3-nompi_hec07895_105
#   icu                        pkgs/main::icu-73.1-h313beb8_0 --> conda-forge::icu-75.1-hfee45f7_0
#   imagecodecs        pkgs/main::imagecodecs-2023.1.23-py31~ --> conda-forge::imagecodecs-2024.9.22-py312h232c411_0
#   krb5                                    1.20.1-hf3e1bf2_1 --> 1.21.3-hf3e1bf2_0
#   lcms2                    pkgs/main::lcms2-2.12-hba8e193_0 --> conda-forge::lcms2-2.16-ha0e7c42_0
#   lerc                       pkgs/main::lerc-3.0-hc377ac9_0 --> conda-forge::lerc-4.0.0-h9a09cb3_0
#   libaec                 pkgs/main::libaec-1.0.4-hc377ac9_1 --> conda-forge::libaec-1.1.3-hebf3989_0
#   libavif              pkgs/main::libavif-0.11.1-h80987f9_0 --> conda-forge::libavif-1.1.1-h45b7238_2
#   libboost            pkgs/main::libboost-1.82.0-h0bc93f9_2 --> conda-forge::libboost-1.85.0-hf763ba5_4
#   libbrotlicommon    pkgs/main::libbrotlicommon-1.0.9-h809~ --> conda-forge::libbrotlicommon-1.1.0-hd74edd7_2
#   libbrotlidec       pkgs/main::libbrotlidec-1.0.9-h80987f~ --> conda-forge::libbrotlidec-1.1.0-hd74edd7_2
#   libbrotlienc       pkgs/main::libbrotlienc-1.0.9-h80987f~ --> conda-forge::libbrotlienc-1.1.0-hd74edd7_2
#   libclang           pkgs/main::libclang-14.0.6-default_h1~ --> conda-forge::libclang-19.1.4-default_hf90f093_0
#   libclang13         pkgs/main::libclang13-14.0.6-default_~ --> conda-forge::libclang13-19.1.4-default_h81d93ff_0
#   libcurl               pkgs/main::libcurl-8.9.1-h3e2b118_0 --> conda-forge::libcurl-8.10.1-h13a7ad3_0
#   libcxx                pkgs/main::libcxx-14.0.6-h848a8c0_0 --> conda-forge::libcxx-19.1.4-ha82da77_0
#   libdeflate          pkgs/main::libdeflate-1.17-h80987f9_1 --> conda-forge::libdeflate-1.22-hd74edd7_0
#   libgfortran5       pkgs/main::libgfortran5-11.3.0-h00934~ --> conda-forge::libgfortran5-13.2.0-hf226fd6_3
#   libglib              pkgs/main::libglib-2.78.4-h0a96307_0 --> conda-forge::libglib-2.82.2-h07bd6cf_0
#   libiconv              pkgs/main::libiconv-1.16-h80987f9_3 --> conda-forge::libiconv-1.17-h0d3ecfb_2
#   libnghttp2         pkgs/main::libnghttp2-1.57.0-h62f6fdd~ --> conda-forge::libnghttp2-1.64.0-h6d7220d_0
#   libpng                pkgs/main::libpng-1.6.39-h80987f9_0 --> conda-forge::libpng-1.6.44-hc14010f_0
#   libpq                   pkgs/main::libpq-12.17-h02f6b3c_0 --> conda-forge::libpq-16.5-h0224a88_0
#   libprotobuf        pkgs/main::libprotobuf-4.25.3-h514c7b~ --> conda-forge::libprotobuf-4.25.3-hc39d83c_1
#   libsolv              pkgs/main::libsolv-0.7.24-h514c7bf_1 --> conda-forge::libsolv-0.7.30-h6c9b7f8_0
#   libthrift          pkgs/main::libthrift-0.15.0-h73c2103_2 --> conda-forge::libthrift-0.19.0-h026a170_1
#   libtiff               pkgs/main::libtiff-4.5.1-h313beb8_0 --> conda-forge::libtiff-4.7.0-hfce79cd_1
#   libwebp-base       pkgs/main::libwebp-base-1.3.2-h80987f~ --> conda-forge::libwebp-base-1.4.0-h93a5062_0
#   libxml2              pkgs/main::libxml2-2.13.1-h0b34f26_2 --> conda-forge::libxml2-2.13.5-hbbdcc80_0
#   llvm-openmp        pkgs/main::llvm-openmp-14.0.6-hc6e570~ --> conda-forge::llvm-openmp-19.1.4-hdb05f8b_0
#   mysql                  pkgs/main::mysql-5.7.24-ha71a6ea_2 --> conda-forge::mysql-9.0.1-h44b9a77_0
#   ncurses                 pkgs/main::ncurses-6.4-h313beb8_0 --> conda-forge::ncurses-6.5-h7bae524_1
#   openssl              pkgs/main::openssl-3.0.15-h80987f9_0 --> conda-forge::openssl-3.4.0-h39f12f2_0
#   orc                       pkgs/main::orc-2.0.1-h937ddfc_0 --> conda-forge::orc-2.0.1-h47ade37_1
#   pcre2                   pkgs/main::pcre2-10.42-hb066dcc_1 --> conda-forge::pcre2-10.44-h297a79d_2
#   pillow             pkgs/main::pillow-10.4.0-py312h80987f~ --> conda-forge::pillow-11.0.0-py312haf37ca6_0
#   pytables           pkgs/main::pytables-3.10.1-py312h905a~ --> conda-forge::pytables-3.10.1-py312h36a7e55_1
#   qt-main             pkgs/main::qt-main-5.15.2-h0917680_10 --> conda-forge::qt-main-5.15.15-h7d33341_0
#   re2                  pkgs/main::re2-2022.04.01-hc377ac9_0 --> conda-forge::re2-2023.09.01-h4cba328_2
#   sqlite                pkgs/main::sqlite-3.45.3-h80987f9_0 --> conda-forge::sqlite-3.47.0-hcd14bea_1
#   streamlit          pkgs/main/osx-arm64::streamlit-1.37.1~ --> conda-forge/noarch::streamlit-1.40.1-pyhd8ed1ab_0
#   tbb                    pkgs/main::tbb-2021.8.0-h48ca7d4_0 --> conda-forge::tbb-2021.13.0-h7b3277c_0
#   zfp                       pkgs/main::zfp-1.0.0-h313beb8_0 --> conda-forge::zfp-1.0.1-h1c5d8ea_2
#   zlib                    pkgs/main::zlib-1.2.13-h18a0788_1 --> conda-forge::zlib-1.3.1-h8359307_2
#   zlib-ng               pkgs/main::zlib-ng-2.0.7-h80987f9_0 --> conda-forge::zlib-ng-2.2.2-hf9b8971_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   arrow-cpp          pkgs/main::arrow-cpp-16.1.0-hbc20fb2_0 --> conda-forge::arrow-cpp-13.0.0-hce30654_49_cpu
#   cyrus-sasl         pkgs/main::cyrus-sasl-2.1.28-h9131b1a~ --> conda-forge::cyrus-sasl-2.1.27-h60b93bd_7
#   grpcio             pkgs/main::grpcio-1.62.2-py312h313beb~ --> conda-forge::grpcio-1.62.2-py312h17030e7_0
#   libarchive         pkgs/main::libarchive-3.7.4-h8f13d7a_0 --> conda-forge::libarchive-3.7.4-h83d404f_0
#   libgfortran        pkgs/main::libgfortran-5.0.0-11_3_0_h~ --> conda-forge::libgfortran-5.0.0-13_2_0_hd922786_3
#   libgrpc              pkgs/main::libgrpc-1.62.2-h62f6fdd_0 --> conda-forge::libgrpc-1.62.2-h9c18a4f_0
#   libllvm14          pkgs/main::libllvm14-14.0.6-h19fdd8a_4 --> conda-forge::libllvm14-14.0.6-hd1a9a77_4
#   libssh2              pkgs/main::libssh2-1.11.0-h3e2b118_0 --> conda-forge::libssh2-1.11.0-h7a5bd25_0
#   pyarrow            pkgs/main::pyarrow-16.1.0-py312hd77eb~ --> conda-forge::pyarrow-13.0.0-py312hd940a8a_49_cpu
#   python                pkgs/main::python-3.12.7-h99e199e_0 --> conda-forge::python-3.12.7-h739c21a_0_cpython
#   tensorflow         pkgs/main::tensorflow-2.17.0-cpu_py31~ --> conda-forge::tensorflow-2.17.0-cpu_py312hb6b62e0_0
#   tensorflow-base    pkgs/main::tensorflow-base-2.17.0-cpu~ --> conda-forge::tensorflow-base-2.17.0-cpu_py312hdc9440d_0
#   tensorflow-estima~ pkgs/main::tensorflow-estimator-2.17.~ --> conda-forge::tensorflow-estimator-2.17.0-cpu_py312ha916e62_0
#   tk                        pkgs/main::tk-8.6.14-h6ba3021_0 --> conda-forge::tk-8.6.13-h5083fa2_1
#   zstd                     pkgs/main::zstd-1.5.6-hfb09047_0 --> conda-forge::zstd-1.5.6-hb46c0d2_0
#
# The following packages will be DOWNGRADED:
#
#   brotli                                   1.0.9-h80987f9_8 --> 1.0.7-hc377ac9_0
#   dask                             2024.8.2-py312hca03da5_0 --> 2024.5.0-py312hca03da5_0
#   dask-core                        2024.8.2-py312hca03da5_0 --> 2024.5.0-py312hca03da5_0
#   dask-expr                          1.1.13-py312hca03da5_0 --> 1.1.0-py312hca03da5_0
#   distributed                      2024.8.2-py312hca03da5_0 --> 2024.5.0-py312hca03da5_0
#
#
#
# Downloading and Extracting Packages:
# tensorflow-base-2.17 | 150.7 MB  |                                       |   0%
# qt-main-5.15.15      | 47.7 MB   |                                       |   0%
#
# pillow-11.0.0        | 39.8 MB   |                                       |   0%
#
#
# libllvm19-19.1.4     | 25.8 MB   |                                       |   0%
#
#
#
# libllvm17-17.0.6     | 23.5 MB   |                                       |   0%
#
#
#
#
# libopencv-4.10.0     | 20.8 MB   |                                       |   0%
#
#
#
#
#
# libllvm14-14.0.6     | 19.6 MB   |                                       |   0%
#
#
#
#
#
#
# libarrow-13.0.0      | 17.3 MB   |                                       |   0%
#
#
#
#
#
#
#
# mysql-server-9.0.1   | 15.7 MB   |                                       |   0%
#
#
#
#
#
#
#
#
# libboost-headers-1.8 | 13.5 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
# python-3.12.7        | 12.4 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# libclang-cpp17-17.0. | 11.8 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# icu-75.1             | 11.3 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-6.1.2         | 8.3 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libclang13-19.1.4    | 8.1 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-arm-cpu- | 7.1 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# streamlit-1.40.1     | 6.7 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgrpc-1.62.2       | 4.8 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-client-9.0.1   | 4.1 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-2024.4.0 | 3.8 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyarrow-13.0.0       | 3.5 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libglib-2.82.2       | 3.5 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf5-1.14.3          | 3.3 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
# libllvm19-19.1.4     | 25.8 MB   |                                       |   0%
#
#
#
# libllvm17-17.0.6     | 23.5 MB   |                                       |   0%
#
#
# libllvm19-19.1.4     | 25.8 MB   | 6                                     |   2%
#
#
#
# libllvm17-17.0.6     | 23.5 MB   | 4                                     |   1%
#
#
#
# libllvm17-17.0.6     | 23.5 MB   | 6                                     |   2%
#
#
# libllvm19-19.1.4     | 25.8 MB   | 9                                     |   3%
#
#
#
# libllvm17-17.0.6     | 23.5 MB   | #1                                    |   3%
#
#
# libllvm19-19.1.4     | 25.8 MB   | #5                                    |   4%
# qt-main-5.15.15      | 47.7 MB   |                                       |   0%
#
#
# libllvm19-19.1.4     | 25.8 MB   | #8                                    |   5%
#
#
#
# libllvm17-17.0.6     | 23.5 MB   | #3                                    |   4%
#
#
# libllvm19-19.1.4     | 25.8 MB   | ##5                                   |   7%
#
#
#
# libllvm17-17.0.6     | 23.5 MB   | #6                                    |   4%
# qt-main-5.15.15      | 47.7 MB   |                                       |   0%
#
#
# libllvm19-19.1.4     | 25.8 MB   | ###                                   |   8%
#
#
#
# libllvm17-17.0.6     | 23.5 MB   | ##3                                   |   6%
# tensorflow-base-2.17 | 150.7 MB  |                                       |   0%
#
#
# libllvm19-19.1.4     | 25.8 MB   | ###7                                  |  10%
# tensorflow-base-2.17 | 150.7 MB  |                                       |   0%
#
#
#
# tensorflow-base-2.17 | 150.7 MB  |                                       |   0%
#
#
# libllvm19-19.1.4     | 25.8 MB   | ####2                                 |  11%
# qt-main-5.15.15      | 47.7 MB   | 1                                     |   0%
#
#
# libllvm19-19.1.4     | 25.8 MB   | ####6                                 |  13%
#
# pillow-11.0.0        | 39.8 MB   |                                       |   0%
#
#
#
# tensorflow-base-2.17 | 150.7 MB  |                                       |   0%
#
#
# libllvm19-19.1.4     | 25.8 MB   | #####1                                |  14%
#
# pillow-11.0.0        | 39.8 MB   |                                       |   0%
#
#
#
# libllvm17-17.0.6     | 23.5 MB   | ###3                                  |   9%
# tensorflow-base-2.17 | 150.7 MB  |                                       |   0%
#
#
# libllvm19-19.1.4     | 25.8 MB   | #####6                                |  15%
#
#
#
# tensorflow-base-2.17 | 150.7 MB  |                                       |   0%
# qt-main-5.15.15      | 47.7 MB   | 2                                     |   1%
#
#
# libllvm19-19.1.4     | 25.8 MB   | ######2                               |  17%
#
# pillow-11.0.0        | 39.8 MB   |                                       |   0%
#
#
#
# libllvm17-17.0.6     | 23.5 MB   | ####                                  |  11%
# tensorflow-base-2.17 | 150.7 MB  |                                       |   0%
#
#
# libllvm19-19.1.4     | 25.8 MB   | ######8                               |  18%
#
#
#
# libllvm17-17.0.6     | 23.5 MB   | ####3                                 |  12%
#
# pillow-11.0.0        | 39.8 MB   | 1                                     |   0%
# tensorflow-base-2.17 | 150.7 MB  |                                       |   0%
# qt-main-5.15.15      | 47.7 MB   | 2                                     |   1%
#
# pillow-11.0.0        | 39.8 MB   | 1                                     |   0%
#
#
#
# libllvm17-17.0.6     | 23.5 MB   | ####6                                 |  13%
#
#
# tensorflow-base-2.17 | 150.7 MB  |                                       |   0%
#
#
#
# libllvm17-17.0.6     | 23.5 MB   | #####                                 |  14%
#
#
# libllvm19-19.1.4     | 25.8 MB   | #######9                              |  22%
# qt-main-5.15.15      | 47.7 MB   | 3                                     |   1%
#
# pillow-11.0.0        | 39.8 MB   | 1                                     |   1%
#
#
# libllvm19-19.1.4     | 25.8 MB   | ########4                             |  23%
#
#
#
# libllvm17-17.0.6     | 23.5 MB   | #####3                                |  14%
#
# pillow-11.0.0        | 39.8 MB   | 2                                     |   1%
# qt-main-5.15.15      | 47.7 MB   | 3                                     |   1%
#
#
# tensorflow-base-2.17 | 150.7 MB  |                                       |   0%
#
#
#
# libllvm17-17.0.6     | 23.5 MB   | #####6                                |  15%
# qt-main-5.15.15      | 47.7 MB   | 3                                     |   1%
#
#
# libllvm19-19.1.4     | 25.8 MB   | #########3                            |  25%
#
#
#
# tensorflow-base-2.17 | 150.7 MB  |                                       |   0%
#
# pillow-11.0.0        | 39.8 MB   | 2                                     |   1%
#
#
# libllvm19-19.1.4     | 25.8 MB   | #########8                            |  27%
# qt-main-5.15.15      | 47.7 MB   | 4                                     |   1%
#
#
#
# tensorflow-base-2.17 | 150.7 MB  |                                       |   0%
# qt-main-5.15.15      | 47.7 MB   | 4                                     |   1%
#
# pillow-11.0.0        | 39.8 MB   | 2                                     |   1%
#
#
# libllvm19-19.1.4     | 25.8 MB   | ##########2                           |  28%
#
#
#
# tensorflow-base-2.17 | 150.7 MB  |                                       |   0%
#
#
# libllvm19-19.1.4     | 25.8 MB   | ##########6                           |  29%
#
# pillow-11.0.0        | 39.8 MB   | 3                                     |   1%
#
#
#
# libllvm17-17.0.6     | 23.5 MB   | ######9                               |  19%
# tensorflow-base-2.17 | 150.7 MB  |                                       |   0%
#
#
# libllvm19-19.1.4     | 25.8 MB   | ###########                           |  30%
#
#
#
# libllvm17-17.0.6     | 23.5 MB   | #######2                              |  20%
# tensorflow-base-2.17 | 150.7 MB  |                                       |   0%
#
# pillow-11.0.0        | 39.8 MB   | 3                                     |   1%
#
#
# libllvm19-19.1.4     | 25.8 MB   | ###########4                          |  31%
# qt-main-5.15.15      | 47.7 MB   | 5                                     |   2%
#
#
#
# libllvm17-17.0.6     | 23.5 MB   | #######5                              |  20%
#
# pillow-11.0.0        | 39.8 MB   | 4                                     |   1%
#
#
# tensorflow-base-2.17 | 150.7 MB  |                                       |   0%
#
#
#
# libllvm17-17.0.6     | 23.5 MB   | #######9                              |  21%
# qt-main-5.15.15      | 47.7 MB   | 5                                     |   2%
#
# pillow-11.0.0        | 39.8 MB   | 4                                     |   1%
#
#
# libllvm19-19.1.4     | 25.8 MB   | ############1                         |  33%
#
#
#
# libllvm17-17.0.6     | 23.5 MB   | ########3                             |  22%
# tensorflow-base-2.17 | 150.7 MB  |                                       |   0%
#
# pillow-11.0.0        | 39.8 MB   | 4                                     |   1%
#
#
# libllvm19-19.1.4     | 25.8 MB   | ############5                         |  34%
#
# pillow-11.0.0        | 39.8 MB   | 5                                     |   1%
#
#
#
# tensorflow-base-2.17 | 150.7 MB  |                                       |   0%
# qt-main-5.15.15      | 47.7 MB   | 6                                     |   2%
#
#
# libllvm19-19.1.4     | 25.8 MB   | ############9                         |  35%
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | 1                                     |   0%
#
# pillow-11.0.0        | 39.8 MB   | 5                                     |   1%
#
#
# libllvm19-19.1.4     | 25.8 MB   | #############4                        |  36%
# qt-main-5.15.15      | 47.7 MB   | 7                                     |   2%
#
#
#
# libllvm17-17.0.6     | 23.5 MB   | #########3                            |  25%
#
# tensorflow-base-2.17 | 150.7 MB  | 1                                     |   0%
# qt-main-5.15.15      | 47.7 MB   | 7                                     |   2%
#
#
#
# libllvm17-17.0.6     | 23.5 MB   | #########6                            |  26%
#
#
# libllvm19-19.1.4     | 25.8 MB   | #############8                        |  37%
# qt-main-5.15.15      | 47.7 MB   | 8                                     |   2%
#
#
# tensorflow-base-2.17 | 150.7 MB  | 1                                     |   0%
#
#
#
# libllvm17-17.0.6     | 23.5 MB   | #########9                            |  27%
#
# pillow-11.0.0        | 39.8 MB   | 5                                     |   2%
# qt-main-5.15.15      | 47.7 MB   | 8                                     |   2%
#
#
# libllvm19-19.1.4     | 25.8 MB   | ##############7                       |  40%
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | 1                                     |   0%
#
# pillow-11.0.0        | 39.8 MB   | 6                                     |   2%
# qt-main-5.15.15      | 47.7 MB   | 8                                     |   2%
#
#
# libllvm19-19.1.4     | 25.8 MB   | ###############1                      |  41%
# qt-main-5.15.15      | 47.7 MB   | 9                                     |   2%
#
# pillow-11.0.0        | 39.8 MB   | 7                                     |   2%
#
#
#
# libllvm17-17.0.6     | 23.5 MB   | ##########8                           |  29%
#
#
# tensorflow-base-2.17 | 150.7 MB  | 1                                     |   0%
#
#
#
# libllvm17-17.0.6     | 23.5 MB   | ###########1                          |  30%
# qt-main-5.15.15      | 47.7 MB   | 9                                     |   3%
#
# pillow-11.0.0        | 39.8 MB   | 7                                     |   2%
#
#
# libllvm19-19.1.4     | 25.8 MB   | ###############9                      |  43%
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | 1                                     |   0%
# qt-main-5.15.15      | 47.7 MB   | #                                     |   3%
#
#
# libllvm19-19.1.4     | 25.8 MB   | ################5                     |  45%
#
#
#
# libllvm17-17.0.6     | 23.5 MB   | ###########9                          |  32%
#
# pillow-11.0.0        | 39.8 MB   | 8                                     |   2%
# qt-main-5.15.15      | 47.7 MB   | #                                     |   3%
#
#
# libllvm19-19.1.4     | 25.8 MB   | ################9                     |  46%
#
# pillow-11.0.0        | 39.8 MB   | 8                                     |   2%
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | 1                                     |   0%
# qt-main-5.15.15      | 47.7 MB   | #                                     |   3%
#
#
# libllvm19-19.1.4     | 25.8 MB   | #################3                    |  47%
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | 1                                     |   0%
#
#
# libllvm19-19.1.4     | 25.8 MB   | #################6                    |  48%
# qt-main-5.15.15      | 47.7 MB   | #1                                    |   3%
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | 1                                     |   1%
#
#
# libllvm19-19.1.4     | 25.8 MB   | ##################                    |  49%
#
# pillow-11.0.0        | 39.8 MB   | 9                                     |   2%
# tensorflow-base-2.17 | 150.7 MB  | 2                                     |   1%
#
#
# libllvm19-19.1.4     | 25.8 MB   | ##################3                   |  50%
#
#
#
# libllvm17-17.0.6     | 23.5 MB   | #############3                        |  36%
#
# pillow-11.0.0        | 39.8 MB   | 9                                     |   3%
# qt-main-5.15.15      | 47.7 MB   | #2                                    |   3%
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | 2                                     |   1%
#
#
# libllvm19-19.1.4     | 25.8 MB   | ##################7                   |  51%
#
# pillow-11.0.0        | 39.8 MB   | #                                     |   3%
# qt-main-5.15.15      | 47.7 MB   | #3                                    |   4%
#
#
#
# libllvm17-17.0.6     | 23.5 MB   | #############9                        |  38%
#
#
# tensorflow-base-2.17 | 150.7 MB  | 2                                     |   1%
#
# pillow-11.0.0        | 39.8 MB   | #                                     |   3%
# qt-main-5.15.15      | 47.7 MB   | #3                                    |   4%
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | 2                                     |   1%
#
# pillow-11.0.0        | 39.8 MB   | #1                                    |   3%
# qt-main-5.15.15      | 47.7 MB   | #4                                    |   4%
#
#
# libllvm19-19.1.4     | 25.8 MB   | ###################5                  |  53%
#
#
#
# libllvm17-17.0.6     | 23.5 MB   | ##############5                       |  39%
#
# tensorflow-base-2.17 | 150.7 MB  | 2                                     |   1%
# qt-main-5.15.15      | 47.7 MB   | #4                                    |   4%
#
#
# libllvm19-19.1.4     | 25.8 MB   | ###################9                  |  54%
#
#
#
# libllvm17-17.0.6     | 23.5 MB   | ##############8                       |  40%
#
# tensorflow-base-2.17 | 150.7 MB  | 2                                     |   1%
#
#
#
# libllvm17-17.0.6     | 23.5 MB   | ###############1                      |  41%
# qt-main-5.15.15      | 47.7 MB   | #5                                    |   4%
#
#
# tensorflow-base-2.17 | 150.7 MB  | 2                                     |   1%
#
#
# libllvm19-19.1.4     | 25.8 MB   | ####################8                 |  56%
#
#
#
# libllvm17-17.0.6     | 23.5 MB   | ###############4                      |  42%
# qt-main-5.15.15      | 47.7 MB   | #5                                    |   4%
#
#
# libllvm19-19.1.4     | 25.8 MB   | #####################3                |  58%
#
# pillow-11.0.0        | 39.8 MB   | #2                                    |   3%
# qt-main-5.15.15      | 47.7 MB   | #6                                    |   4%
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | 3                                     |   1%
#
#
#
# libllvm17-17.0.6     | 23.5 MB   | ###############9                      |  43%
# qt-main-5.15.15      | 47.7 MB   | #6                                    |   5%
#
# pillow-11.0.0        | 39.8 MB   | #3                                    |   4%
#
#
# libllvm19-19.1.4     | 25.8 MB   | #####################6                |  59%
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | 3                                     |   1%
# qt-main-5.15.15      | 47.7 MB   | #7                                    |   5%
#
# pillow-11.0.0        | 39.8 MB   | #4                                    |   4%
#
#
#
# libllvm17-17.0.6     | 23.5 MB   | ################5                     |  45%
#
#
# libllvm19-19.1.4     | 25.8 MB   | ######################3               |  60%
# tensorflow-base-2.17 | 150.7 MB  | 3                                     |   1%
# qt-main-5.15.15      | 47.7 MB   | #9                                    |   5%
#
#
#
# ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | ############1                         |  33%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-client-9.0.1   | 4.1 MB    | ##################################1   |  92%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyarrow-13.0.0       | 3.5 MB    | ###############################8      |  86%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libglib-2.82.2       | 3.5 MB    | ####1                                 |  11%
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | ############1                         |  33%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libglib-2.82.2       | 3.5 MB    | #######                               |  19%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-client-9.0.1   | 4.1 MB    | ###################################   |  95%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyarrow-13.0.0       | 3.5 MB    | #################################7    |  91%
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | ############1                         |  33%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyarrow-13.0.0       | 3.5 MB    | ###################################8  |  97%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libglib-2.82.2       | 3.5 MB    | #########1                            |  25%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-client-9.0.1   | 4.1 MB    | ###################################7  |  97%
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | ############1                         |  33%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libglib-2.82.2       | 3.5 MB    | #############6                        |  37%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf5-1.14.3          | 3.3 MB    | 1                                     |   0%
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | ############2                         |  33%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libglib-2.82.2       | 3.5 MB    | ################6                     |  45%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf5-1.14.3          | 3.3 MB    | #4                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf5-1.14.3          | 3.3 MB    | ##6                                   |   7%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-client-9.0.1   | 4.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-client-9.0.1   | 4.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libglib-2.82.2       | 3.5 MB    | ###################5                  |  53%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyarrow-13.0.0       | 3.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# libclang-cpp17-17.0. | 11.8 MB   | ######################9               |  62%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | ############2                         |  33% [A
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf5-1.14.3          | 3.3 MB    | ###8                                  |  10%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libglib-2.82.2       | 3.5 MB    | #####################8                |  59%
#
#
#
#
#
#
#
#
#
#
# libclang-cpp17-17.0. | 11.8 MB   | #######################1              |  62%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | ############2                         |  33% [A
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf5-1.14.3          | 3.3 MB    | #####6                                |  15%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libglib-2.82.2       | 3.5 MB    | #########################3            |  69%
#
#
#
#
#
#
#
#
#
#
# libclang-cpp17-17.0. | 11.8 MB   | #######################3              |  63%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libglib-2.82.2       | 3.5 MB    | ############################3         |  77%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | ############3                         |  33%
#
#
#
#
#
#
#
#
#
#
# libclang-cpp17-17.0. | 11.8 MB   | #######################5              |  64%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf5-1.14.3          | 3.3 MB    | ########6                             |  23%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libglib-2.82.2       | 3.5 MB    | ##############################8       |  83%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | ############3                         |  33% [A
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libglib-2.82.2       | 3.5 MB    | #################################3    |  90%
#
#
#
#
#
#
#
#
#
#
# libclang-cpp17-17.0. | 11.8 MB   | #######################6              |  64%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf5-1.14.3          | 3.3 MB    | ##########9                           |  29%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libglib-2.82.2       | 3.5 MB    | ###################################6  |  96%
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | ############3                         |  33%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf5-1.14.3          | 3.3 MB    | ############4                         |  34%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | ############3                         |  33%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf5-1.14.3          | 3.3 MB    | ##############7                       |  40%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libglib-2.82.2       | 3.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf5-1.14.3          | 3.3 MB    | ################3                     |  44%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | ############4                         |  34% [A
#
#
#
#
#
#
#
#
#
#
# libclang-cpp17-17.0. | 11.8 MB   | ########################2             |  66%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf5-1.14.3          | 3.3 MB    | #################9                    |  49%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | ############4                         |  34% [A
#
#
#
#
#
#
#
#
#
#
# libclang-cpp17-17.0. | 11.8 MB   | ########################4             |  66%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | ############4                         |  34% [A
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf5-1.14.3          | 3.3 MB    | ###################3                  |  52%
#
#
#
#
#
#
#
#
#
#
# libclang-cpp17-17.0. | 11.8 MB   | ########################6             |  67%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | ############4                         |  34% [A
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf5-1.14.3          | 3.3 MB    | #####################1                |  57%
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | ############4                         |  34%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf5-1.14.3          | 3.3 MB    | #######################               |  62%
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | ############5                         |  34%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf5-1.14.3          | 3.3 MB    | ########################4             |  66%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf5-1.14.3          | 3.3 MB    | #########################6            |  69%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | ############5                         |  34%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf5-1.14.3          | 3.3 MB    | ###########################2          |  74%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | ############5                         |  34% [A
#
#
#
#
#
#
#
#
#
#
# libclang-cpp17-17.0. | 11.8 MB   | #########################3            |  69%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | ############5                         |  34%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf5-1.14.3          | 3.3 MB    | ##############################4       |  82%
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | ############6                         |  34%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf5-1.14.3          | 3.3 MB    | #################################     |  89%
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | ############6                         |  34%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf5-1.14.3          | 3.3 MB    | ##################################8   |  94%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
# libclang-cpp17-17.0. | 11.8 MB   | ##########################            |  70%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf5-1.14.3          | 3.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | ############6                         |  34%
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | ############6                         |  34%
#
#
#
#
#
#
#
#
#
#
# libclang-cpp17-17.0. | 11.8 MB   | ##########################3           |  71%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | ############6                         |  34% [A
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | ############6                         |  34%
#
#
#
#
#
#
#
#
#
#
# libclang-cpp17-17.0. | 11.8 MB   | ##########################8           |  72%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | ############7                         |  34%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | ############7                         |  34% [A
#
#
#
#
#
#
#
#
#
#
# libclang-cpp17-17.0. | 11.8 MB   | ###########################1          |  73%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | ############7                         |  35% [A
#
#
#
#
#
#
#
#
#
#
# libclang-cpp17-17.0. | 11.8 MB   | ###########################4          |  74%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | ############7                         |  35% [A
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | ############8                         |  35%
#
#
#
#
#
#
#
#
#
#
# libclang-cpp17-17.0. | 11.8 MB   | ###########################7          |  75%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | ############8                         |  35%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | ############8                         |  35% [A
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | ############9                         |  35%
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | ############9                         |  35%
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | ############9                         |  35%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | #############                         |  35%
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | #############                         |  35%
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | #############                         |  35%
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | #############                         |  35%
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | #############1                        |  35%
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | #############1                        |  36%
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | #############1                        |  36%
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | #############1                        |  36%
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | #############2                        |  36%
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | #############2                        |  36%
#
#
#
#
#
#
#
#
#
#
# libclang-cpp17-17.0. | 11.8 MB   | ###############################2      |  85%
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | #############2                        |  36%
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | #############2                        |  36%
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | #############3                        |  36%
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | #############3                        |  36%
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | #############3                        |  36%
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | #############4                        |  36%
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | #############4                        |  36%
#
#
#
#
#
#
#
#
#
#
# libclang-cpp17-17.0. | 11.8 MB   | ###################################9  |  97%
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | #############5                        |  37%
#
#
#
#
#
#
#
#
#
#
# libclang-cpp17-17.0. | 11.8 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 150.7 MB  | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
## Import important libraries for prediction
from keras.utils import load_img, img_to_array
from keras.models import Model, load_model
import cv2

# %%
import numpy as np

# %%
## Loading the pre-trained mask detection model
model = load_model("Mask_NoMask.h5")
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/optimizers/base_optimizer.py:33: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.

# %%
### Starting the camera
cam = cv2.VideoCapture(0)

###Detect Face
face_class = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

while True:
    _, img = cam.read()
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_class.detectMultiScale(gray, 1.3, 5)
    for (x, y, w, h) in faces:
        face = img[y:y+h, x:x+w]
        face = cv2.resize(face, (224,224))
        face = img_to_array(face)
        face = np.expand_dims(face, axis = 0)
        face = preprocess_input(face)
        
        text = ""
        colour = (0,0,0)
        (mask, withoutmask) = model.predict(face)[0]
        if mask > withoutmask:
            text = 'Mask Detected'
            colour = (0,225,0)
        else:
            text = 'No Mask'
            colour = (0,0,225)
        
        
        cv2.rectangle(img, (x, y), (x+w, y+h), colour, 2)
        cv2.putText(img , text, (x, y -15), cv2.FONT_HERSHEY_SIMPLEX, 0.9, colour, 2)
    
    cv2.imshow('My Mask Detector', img)
    if cv2.waitKey(1) == 13:
        break
        
cam.release()
cv2.destroyAllWindows()
